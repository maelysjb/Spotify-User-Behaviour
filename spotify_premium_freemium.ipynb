# %%
import pandas as pd

# initialize path to folder
path_init = "/Users/maelys/Desktop/BUSA 400/Github Upload/DATA"

# %%
# open training set: log mini
spotify_training = pd.read_csv(path_init +"/Spotify_AIcrowd_Training_Set_And_Track_Features_Mini/training_set/log_mini.csv")
spotify_training.head()
# Out:
#                                session_id  session_position  session_length  \
# 0  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1              20
# 1  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2              20
# 2  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3              20
# 3  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4              20
# 4  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5              20
#
#                            track_id_clean  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False   False
# 1  t_9099cd7b-c238-47b7-9381-f23f2c1d1043   False   False   False
# 2  t_fc5df5ba-5396-49a7-8b29-35d0d28249e0   False   False   False
# 3  t_23cff8d6-d874-4b20-83dc-94e450e8aa20   False   False   False
# 4  t_64f3743c-f624-46bb-a579-0f3f9a07a123   False   False   False
#
#    not_skipped  context_switch  no_pause_before_play  ...  \
# ...

# %%
# open tf: track features
spotify_tracks = pd.read_csv(path_init +"/Spotify_AIcrowd_Training_Set_And_Track_Features_Mini/track_features/tf_mini.csv")
spotify_tracks.head()
# Out:
#                                  track_id    duration  release_year  \
# 0  t_a540e552-16d4-42f8-a185-232bd650ea7d  109.706673          1950
# 1  t_67965da0-132b-4b1e-8a69-0ef99b32287c  187.693329          1950
# 2  t_0614ecd3-a7d5-40a1-816e-156d5872a467  160.839996          1951
# 3  t_070a63a0-744a-434e-9913-a97b02926a29  175.399994          1951
# 4  t_d6990e17-9c31-4b01-8559-47d9ce476df1  369.600006          1951
#
#    us_popularity_estimate  acousticness  beat_strength  bounciness  \
# 0               99.975414      0.458040       0.519497    0.504949
# 1               99.969430      0.916272       0.419223    0.545530
# 2               99.602549      0.812884       0.425890    0.508280
# 3               99.665018      0.396854       0.400934    0.359990
# 4               99.991764      0.728831       0.371328    0.335115
#
#    danceability  dyn_range_mean    energy  ...  time_signature   valence  \
# 0      0.399767        7.511880  0.817709  ...               4  0.935512
# ...

# %%
spotify_training['premium'].value_counts()
# might need to rebalance the dataset
# Out:
# True     136053
# False     31827
# Name: premium, dtype: int64

# %%
spotify_training.groupby('premium').min()
# Out:
#                                      session_id  session_position  \
# premium
# False    0_00030fe3-298d-4930-8534-fc5a9b82971b                 1
# True     0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
#
#          session_length                          track_id_clean  skip_1  \
# premium
# False                10  t_00007fba-6bd3-449d-85dd-54d4aea397c2   False
# True                 10  t_00020dc1-1b82-43e9-8327-77b074bdf626   False
#
#          skip_2  skip_3  not_skipped  context_switch  no_pause_before_play  \
# premium
# False     False   False        False               0                     0
# True      False   False        False               0                     0
#
#          short_pause_before_play  long_pause_before_play  \
# premium
# False                          0                       0
# True                           0                       0
#
#          hist_user_behavior_n_seekfwd  hist_user_behavior_n_seekback  \
# premium
# ...

# %%
spotify_training.groupby('premium').mean()
# Out:
#          session_position  session_length    skip_1    skip_2    skip_3  \
# premium
# False            9.056619       17.115405  0.449147  0.533761  0.652936
# True             9.388907       17.777307  0.415037  0.513300  0.647314
#
#          not_skipped  context_switch  no_pause_before_play  \
# premium
# False       0.330254        0.031326              0.758664
# True        0.333495        0.043145              0.769693
#
#          short_pause_before_play  long_pause_before_play  \
# premium
# False                   0.126685                0.179376
# True                    0.151301                0.171301
#
#          hist_user_behavior_n_seekfwd  hist_user_behavior_n_seekback  \
# premium
# False                        0.046219                       0.057090
# True                         0.037199                       0.043726
#
#          hist_user_behavior_is_shuffle  hour_of_day
# premium
# False                         0.201181    14.026801
# ...

# %%
spotify_training.groupby('premium').std()
# Out:
#          session_position  session_length    skip_1    skip_2    skip_3  \
# premium
# False            5.362935        3.645431  0.497415  0.498867  0.476044
# True             5.477664        3.355285  0.492730  0.499825  0.477808
#
#          not_skipped  context_switch  no_pause_before_play  \
# premium
# False       0.470312        0.174199              0.427900
# True        0.471463        0.203184              0.421031
#
#          short_pause_before_play  long_pause_before_play  \
# premium
# False                   0.332625                0.383673
# True                    0.358344                0.376773
#
#          hist_user_behavior_n_seekfwd  hist_user_behavior_n_seekback  \
# premium
# False                        0.535224                       0.928731
# True                         0.315338                       0.502170
#
#          hist_user_behavior_is_shuffle  hour_of_day
# premium
# False                         0.400890     6.629867
# ...

# %%
spotify_training.groupby('premium').max()
# Out:
#                                      session_id  session_position  \
# premium
# False    0_0ea956f2-3424-4b7b-8812-1da3344f077f                20
# True     0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                20
#
#          session_length                          track_id_clean  skip_1  \
# premium
# False                20  t_fffc5585-4ff9-4f73-a5ae-c67afa99fbb5    True
# True                 20  t_fffe4528-f29c-467c-a751-e9db03964faa    True
#
#          skip_2  skip_3  not_skipped  context_switch  no_pause_before_play  \
# premium
# False      True    True         True               1                     1
# True       True    True         True               1                     1
#
#          short_pause_before_play  long_pause_before_play  \
# premium
# False                          1                       1
# True                           1                       1
#
#          hist_user_behavior_n_seekfwd  hist_user_behavior_n_seekback  \
# premium
# ...

# %%
spotify_training.describe()
# Out:
#        session_position  session_length  context_switch  no_pause_before_play  \
# count     167880.000000   167880.000000   167880.000000         167880.000000
# mean           9.325911       17.651823        0.040904              0.767602
# std            5.457638        3.422025        0.198069              0.422363
# min            1.000000       10.000000        0.000000              0.000000
# 25%            5.000000       15.000000        0.000000              1.000000
# 50%            9.000000       20.000000        0.000000              1.000000
# 75%           14.000000       20.000000        0.000000              1.000000
# max           20.000000       20.000000        1.000000              1.000000
#
#        short_pause_before_play  long_pause_before_play  \
# count            167880.000000           167880.000000
# mean                  0.146635                0.172832
# std                   0.353742                0.378103
# ...
